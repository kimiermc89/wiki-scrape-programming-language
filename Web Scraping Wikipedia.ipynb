# %%
import csv
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://en.wikipedia.org/wiki/Comparison_of_programming_languages")
soup = BeautifulSoup(html, "html.parser")
table = soup.findAll("table", {"class":"wikitable"})[0]
rows = table.findAll("tr")

with open("language.csv", "wt+", newline="") as f:
    writer = csv.writer(f)
    for i in rows:
        row = []
        for cell in i.findAll(["td", "th"]):
            row.append(cell.get_text())
        writer.writerow(row)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-3-e68a8569f8fc> in <module>
#       8 rows = table.findAll("tr")
#       9
# ---> 10 with open("language.csv", "wt+", newline="") as f:
#      11     writer = csv.writer(f)
#      12     for i in rows:
#
# PermissionError: [Errno 13] Permission denied: 'language.csv'

# %%
import pandas as pd
a = pd.read_csv("language.csv")
a.head()
# Out:
#                              Language\n  \
# 0  1C:Enterprise programming language\n
# 1                    ActionScript 3.0\n
# 2                                 Ada\n
# 3                               Aldor\n
# 4                            ALGOL 58\n
#
#                                       Intended use\n Imperative\n  \
# 0  Application, RAD, �business, general, web, mob...        Yes\n
# 1                    Application, client-side, web\n        Yes\n
# 2          Application, embedded, realtime, system\n        Yes\n
# 3       Highly domain-specific, symbolic computing\n        Yes\n
# 4                                      Application\n        Yes\n
#
#   Object-oriented\n Functional\n Procedural\n Generic\n Reflective\n  \
# 0                \n        Yes\n        Yes\n     Yes\n        Yes\n
# 1             Yes\n        Yes\n           \n        \n           \n
# 2          Yes[2]\n           \n     Yes[3]\n  Yes[4]\n           \n
# 3             Yes\n        Yes\n           \n        \n           \n
# 4                \n           \n           \n        \n           \n
#
#   Event-driven\n                             Other paradigm(s)\n  \
# 0          Yes\n  Object-based,\nPrototype-based programming\n\n
# 1          Yes\n                                              \n
# 2             \n                concurrent,[5] distributed,[6]\n
# 3             \n                                              \n
# 4             \n                                              \n
#
#                                    Standardized?\n
# 0                                             No\n
# 1                                     1996, ECMA\n
# 2  1983, 2005, 2012, ANSI, ISO, GOST 27831-88[7]\n
# 3                                             No\n
# 4                                             No\n

# %%
a.ndim
# Out:
# 2

# %%
a.info
# Out:
# <bound method DataFrame.info of                                Language\n  \
# 0    1C:Enterprise programming language\n
# 1                      ActionScript 3.0\n
# 2                                   Ada\n
# 3                                 Aldor\n
# 4                              ALGOL 58\n
# ..                                    ...
# 130                    Wolfram Language\n
# 131                                  XL\n
# 132                                Xojo\n
# 133                        XPath/XQuery\n
# 134                                 Zsh\n
#
#                                         Intended use\n Imperative\n  \
# 0    Application, RAD, �business, general, web, mob...        Yes\n
# 1                      Application, client-side, web\n        Yes\n
# 2            Application, embedded, realtime, system\n        Yes\n
# 3         Highly domain-specific, symbolic computing\n        Yes\n
# 4                                        Application\n        Yes\n
# ..                                                 ...          ...
# 130                                Symbolic language\n        Yes\n
# 131                                                 \n        Yes\n
# 132                   Application, RAD, general, web\n        Yes\n
# 133            Databases, data processing, scripting\n           \n
# 134                                 Shell, scripting\n        Yes\n
#
#     Object-oriented\n Functional\n Procedural\n Generic\n Reflective\n  \
# 0                  \n        Yes\n        Yes\n     Yes\n        Yes\n
# 1               Yes\n        Yes\n           \n        \n           \n
# 2            Yes[2]\n           \n     Yes[3]\n  Yes[4]\n           \n
# 3               Yes\n        Yes\n           \n        \n           \n
# 4                  \n           \n           \n        \n           \n
# ..                ...          ...          ...       ...          ...
# 130             Yes\n        Yes\n        Yes\n     Yes\n        Yes\n
# 131             Yes\n           \n           \n        \n           \n
# 132             Yes\n           \n        Yes\n        \n        Yes\n
# 133                \n        Yes\n           \n        \n           \n
# 134                \n           \n        Yes\n        \n           \n
#
#     Event-driven\n                             Other paradigm(s)\n  \
# 0            Yes\n  Object-based,\nPrototype-based programming\n\n
# 1            Yes\n                                              \n
# 2               \n                concurrent,[5] distributed,[6]\n
# 3               \n                                              \n
# 4               \n                                              \n
# ..             ...                                             ...
# 130          Yes\n                            logic, distributed\n
# 131             \n                           concept programming\n
# 132          Yes\n                                              \n
# 133             \n                                 tree-oriented\n
# 134             \n                              loadable modules\n
#
#                                        Standardized?\n
# 0                                                 No\n
# 1                                         1996, ECMA\n
# 2      1983, 2005, 2012, ANSI, ISO, GOST 27831-88[7]\n
# 3                                                 No\n
# 4                                                 No\n
# ..                                                 ...
# 130                                               No\n
# 131                                               No\n
# 132                                               No\n
# 133  W3C 1999 XPath 1, 2010 XQuery 1, 2014 XPath/XQ...
# 134                                               No\n
#
# [135 rows x 11 columns]>
